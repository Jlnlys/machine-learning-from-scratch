# %% [markdown]
# <a href="https://colab.research.google.com/github/Jlnlys/machine-learning-from-scratch/blob/main/KNN.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np

# %%
class my_knn():
    def __init__(self,near):
      self.near = near
      self.X_train = None
      self.y_train = None

    def fit(self,X,y):
      self.X_train = X
      self.y_train = y

    def predict(self,D):
      y_pred = np.zeros(D.shape[0])
      for i in range(D.shape[0]):
        fin = np.subtract(self.X_train,D[i])
        fin = fin*fin
        fin = np.sum(fin,axis=1)
        fin = np.sqrt(fin)
        fin = np.argsort(fin)
        fin = fin[:self.near]
        fin = self.y_train[fin]
        fin = np.bincount(fin)
        y_pred[i] = np.argmax(fin)
      return y_pred

# %%
import pandas as pd

# %%
cols = ["fLength","fWidth","fSize","fConc","fConc1","fAsym","fM3Long","fM3Trans","fAlpha","fDist","class"]
df = pd.read_csv("magic04.data",names=cols)
df.head()
# Out:
#     fLength    fWidth   fSize   fConc  fConc1     fAsym  fM3Long  fM3Trans  \
# 0   28.7967   16.0021  2.6449  0.3918  0.1982   27.7004  22.0110   -8.2027
# 1   31.6036   11.7235  2.5185  0.5303  0.3773   26.2722  23.8238   -9.9574
# 2  162.0520  136.0310  4.0612  0.0374  0.0187  116.7410 -64.8580  -45.2160
# 3   23.8172    9.5728  2.3385  0.6147  0.3922   27.2107  -6.4633   -7.1513
# 4   75.1362   30.9205  3.1611  0.3168  0.1832   -5.5277  28.5525   21.8393
#
#     fAlpha     fDist class
# 0  40.0920   81.8828     g
# 1   6.3609  205.2610     g
# 2  76.9600  256.7880     g
# 3  10.4490  116.7370     g
# 4   4.6480  356.4620     g

# %%
df["class"] = (df["class"] == "g").astype(int)

# %%
train,valid,test = np.split(df.sample(frac=1),[int(0.6*len(df)),int(0.8*len(df))])
# Out:
# /usr/local/lib/python3.12/dist-packages/numpy/_core/fromnumeric.py:57: FutureWarning: 'DataFrame.swapaxes' is deprecated and will be removed in a future version. Please use 'DataFrame.transpose' instead.
#   return bound(*args, **kwds)

# %%
from sklearn.preprocessing import StandardScaler
from imblearn.over_sampling import RandomOverSampler

# %%
def standarlize(dataframe,random=True):
  x = dataframe[dataframe.columns[:-1]].values
  y = dataframe[dataframe.columns[-1]].values
  scaler = StandardScaler()
  x = scaler.fit_transform(x)
  if random:
    ros = RandomOverSampler()
    x,y = ros.fit_resample(x,y)

  return x,y

# %%
x_train,y_train = standarlize(train)
x_valid,y_valid = standarlize(valid,False)
x_test,y_test = standarlize(test,False)

# %%
len(y_train[y_train==0])
# Out:
# 7477

# %%
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import  classification_report

# %% [markdown]
# Test with my_knn class

# %%
my_knn = my_knn(5)
my_knn.fit(x_train,y_train)
y_pred = my_knn.predict(x_test)
print(classification_report(y_test,y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.73      0.73      0.73      1365
#            1       0.85      0.85      0.85      2439
#
#     accuracy                           0.81      3804
#    macro avg       0.79      0.79      0.79      3804
# weighted avg       0.81      0.81      0.81      3804

# %% [markdown]
# Test with the Sklearn

# %%
knn = KNeighborsClassifier(5)
knn.fit(x_train,y_train)
y_pred = knn.predict(x_test)
print(classification_report(y_test,y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.73      0.73      0.73      1365
#            1       0.85      0.85      0.85      2439
#
#     accuracy                           0.81      3804
#    macro avg       0.79      0.79      0.79      3804
# weighted avg       0.81      0.81      0.81      3804

# %% [markdown]
# That's it! I built this KNN from scratch to really understand how it works under the hood, instead of just calling .fit(). I compared it against scikit-learn's implementation and got the same results, which confirms it works correctly.
# More algorithms from scratch coming soon!
#
# https://github.com/Jlnlys
